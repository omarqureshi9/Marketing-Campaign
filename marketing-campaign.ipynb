# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/kaggle/input/campaign-data/campaign_data.csv')
dataset
# Out:
#       CampaignID  GoalAmount   RaisedAmount  DurationDays  NumBackers  \
# 0      CID_00000       76159   73518.028955            15        1903
# 1      CID_00001       69394   60068.683288            49         469
# 2      CID_00002       18652   22958.153470            58         148
# 3      CID_00003       19487   24229.048390            39         780
# 4      CID_00004       26734   17984.630311            68        1622
# ...          ...         ...            ...           ...         ...
# 99995  CID_99995       80417  112068.932642            26         870
# 99996  CID_99996       85052  100430.502040            78        1146
# 99997  CID_99997       68407  102020.936312            87         636
# 99998  CID_99998       59749   67026.111706            51        1276
# 99999  CID_99999       39913   54863.288105            73         695
#
#       Category LaunchMonth    Country Currency  OwnerExperience VideoIncluded  \
# ...

# %%
data=dataset.copy()
data.isnull().sum()
# Out:
# CampaignID             0
# GoalAmount             0
# RaisedAmount           0
# DurationDays           0
# NumBackers             0
# Category               0
# LaunchMonth            0
# Country                0
# Currency               0
# OwnerExperience        0
# VideoIncluded          0
# SocialMediaPresence    0
# NumUpdates             0
# IsSuccessful           0
# dtype: int64

# %%
sns.scatterplot(x='GoalAmount', y='RaisedAmount', data=data, hue='IsSuccessful')
plt.show()

# %% [markdown]
# #### This graph shows that a campaign is deemed successful if the raised amount surpasses the goal amount. If the raised amount falls below the goal amount, the campaign is termed "not sucessful"

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='RaisedAmount', y='DurationDays', data=data, hue='IsSuccessful')
plt.show()

# %% [markdown]
# #### This graph shows that if the raised amount for a campaign is above 100,000, it is sucessful. Additionally, this plot also reflects that if the raised amount is 60,000 or below, the campaign is more likely to be to be unsuccessful than sucessful.
